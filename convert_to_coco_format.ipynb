# %% [markdown]
# ### This notebook explores the structure of COCO data set and how to create labels for your custom dataset with similar structure

# %%
import numpy
import multiprocessing
import time
import os
import json

import openslide
from SlideRunner.dataAccess.database import Database
from SlideRunner.dataAccess.annotations import *

from pathlib import Path
path = Path('./')

import sys
sys.path.append('../')

# you need to create a "utils" folder with the following two files
from utils.image_utils import *
from utils.coco_format_labels_creation import *

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
root_dir = os.getcwd()
database_dir = os.path.join(root_dir, 'databases')

#Specify the database SQL file
db_file = 'MITOS_WSI_CMC_COADEL_TR.sqlite'
db_path = os.path.join(database_dir, db_file)

#Specify directory of whole slide images
slide_dir = os.path.join(root_dir, 'WSI')

# %% [markdown]
# ### Read in a new slide and load the file into memory

# %%
#Specify a slide number
slide_num = 15 # must be in this list [1,2, ..., 21]
filename = os.listdir(slide_dir)[slide_num]

#Get all the details about a paricular slide
slide_path = os.path.join(slide_dir, filename)  #basepath + os.sep + filename
slide = openslide.open_slide(str(slide_path))

# %%
#database.open(os.path.join(database_dir, database))
database = Database()
DB = database.open(db_path)

getslides = """SELECT uid, filename FROM Slides"""
currslide, filename = DB.execute(getslides).fetchall()[slide_num]

# %%
# Print the label for each annotation
for k in database.annotations.keys():
    print(k, database.annotations[k].agreedLabel())

# %%
#load the WSI into memory
database.loadIntoMemory(currslide)

# %%
# Print the label for each annotation
len(database.annotations.keys())
#for k in database.annotations.keys():
#    print(k, database.annotations[k].agreedLabel())
# Out:
# 722

# %%
getslides = """SELECT uid, filename FROM Slides"""
#currslide, filename = DB.execute(getslides).fetchall()[slide_num]

# %%
DB.execute(getslides).fetchall()
# Out:
# [(1, 'a8773be388e12df89edd.svs'),
#  (2, '460906c0b1fe17ea5354.svs'),
#  (3, '2d56d1902ca533a5b509.svs'),
#  (5, 'd0423ef9a648bb66a763.svs'),
#  (6, '50cf88e9a33df0c0c8f9.svs'),
#  (7, 'da18e7b9846e9d38034c.svs'),
#  (8, 'd7a8af121d7d4f3fbf01.svs'),
#  (9, '2191a7aa287ce1d5dbc0.svs'),
#  (10, '69a02453620ade0edefd.svs'),
#  (11, 'c4b95da36e32993289cb.svs'),
#  (12, 'fa4959e484beec77543b.svs'),
#  (13, '72c93e042d0171a61012.svs'),
#  (14, '4eee7b944ad5e46c60ce.svs'),
#  (15, 'b1bdee8e5e3372174619.svs'),
#  (16, '3d3d04eca056556b0b26.svs'),
#  (17, '084383c18b9060880e82.svs'),
#  (18, 'e09512d530d933e436d5.svs'),
#  (19, 'd37ab62158945f22deed.svs'),
#  (20, 'deb768e5efb9d1dcbc13.svs'),
#  (21, '022857018aa597374b6c.svs'),
#  (22, '13528f1921d4f1f15511.svs')]

# %%
slide_path = os.path.join(slide_dir, filename)  #basepath + os.sep + filename
slide = openslide.open_slide(str(slide_path))

#load the WSI into memory
database.loadIntoMemory(currslide)

slide.associated_images['macro'], slide.properties
for k in slide.properties.items():
    print(k)
# Out:
# ('aperio.AppMag', '40')
# ('aperio.DSR ID', '130.133.91.37')
# ('aperio.Date', '09/24/18')
# ('aperio.DisplayColor', '0')
# ('aperio.Exposure Scale', '0.000001')
# ('aperio.Exposure Time', '109')
# ('aperio.Filename', '084383c18b9060880e82')
# ('aperio.Focus Offset', '0.000000')
# ('aperio.ICC Profile', 'ScanScope v1')
# ('aperio.ImageID', '49817')
# ('aperio.Left', '21.099384')
# ('aperio.LineAreaXOffset', '0.003040')
# ('aperio.LineAreaYOffset', '-0.011652')
# ('aperio.LineCameraSkew', '-0.000450')
# ('aperio.MPP', '0.2533')
# ('aperio.OriginalHeight', '82253')
# ('aperio.OriginalWidth', '62560')
# ('aperio.ScanScope ID', 'VETWE12MIC')
# ('aperio.SessonMode', 'NR')
# ('aperio.StripeWidth', '1840')
# ('aperio.Time', '10:46:00')
# ('aperio.Time Zone', 'GMT+02:00')
# ('aperio.Title', '084383c18b9060880e82')
# ('aperio.Top', '22.655859')
# ('aperio.User', 'e075590f-9409-461d-b086-af2ffaf0ad27')
# ('openslide.comment', 'Aperio Image Library v12.0.15 ..62560x82253 [0,100 61199x82153] (240x240) J2K/KDU Q=70|AppMag = 40|StripeWidth = 1840|ScanScope ID = VETWE12MIC|Filename = 084383c18b9060880e82|Title = 084383c18b9060880e82|Date = 09/24/18|Time = 10:46:00|Time Zone = GMT+02:00|User = e075590f-9409-461d-b086-af2ffaf0ad27|MPP = 0.2533|Left = 21.099384|Top = 22.655859|LineCameraSkew = -0.000450|LineAreaXOffset = 0.003040|LineAreaYOffset = -0.011652|Focus Offset = 0.000000|DSR ID = 130.133.91.37|ImageID = 49817|Exposure Time = 109|Exposure Scale = 0.000001|DisplayColor = 0|SessonMode = NR|OriginalWidth = 62560|OriginalHeight = 82253|ICC Profile = ScanScope v1\n')
# ('openslide.level-count', '4')
# ('openslide.level[0].downsample', '1')
# ('openslide.level[0].height', '82153')
# ('openslide.level[0].tile-height', '240')
# ('openslide.level[0].tile-width', '240')
# ('openslide.level[0].width', '61199')
# ('openslide.level[1].downsample', '4.0001223907402661')
# ('openslide.level[1].height', '20538')
# ('openslide.level[1].tile-height', '240')
# ('openslide.level[1].tile-width', '240')
# ('openslide.level[1].width', '15299')
# ('openslide.level[2].downsample', '16.002837806615346')
# ('openslide.level[2].height', '5134')
# ('openslide.level[2].tile-height', '240')
# ('openslide.level[2].tile-width', '240')
# ('openslide.level[2].width', '3824')
# ('openslide.level[3].downsample', '32.005675613230693')
# ('openslide.level[3].height', '2567')
# ('openslide.level[3].tile-height', '240')
# ('openslide.level[3].tile-width', '240')
# ('openslide.level[3].width', '1912')
# ('openslide.mpp-x', '0.25330000000000003')
# ('openslide.mpp-y', '0.25330000000000003')
# ('openslide.objective-power', '40')
# ('openslide.quickhash-1', 'dcf10e2bfa8b2f0e4d2203557bfe1120ad853be12f5ee360056dc6389bf662ba')
# ('openslide.vendor', 'aperio')
# ('tiff.ImageDescription', 'Aperio Image Library v12.0.15 ..62560x82253 [0,100 61199x82153] (240x240) J2K/KDU Q=70|AppMag = 40|StripeWidth = 1840|ScanScope ID = VETWE12MIC|Filename = 084383c18b9060880e82|Title = 084383c18b9060880e82|Date = 09/24/18|Time = 10:46:00|Time Zone = GMT+02:00|User = e075590f-9409-461d-b086-af2ffaf0ad27|MPP = 0.2533|Left = 21.099384|Top = 22.655859|LineCameraSkew = -0.000450|LineAreaXOffset = 0.003040|LineAreaYOffset = -0.011652|Focus Offset = 0.000000|DSR ID = 130.133.91.37|ImageID = 49817|Exposure Time = 109|Exposure Scale = 0.000001|DisplayColor = 0|SessonMode = NR|OriginalWidth = 62560|OriginalHeight = 82253|ICC Profile = ScanScope v1\n')
# ('tiff.ResolutionUnit', 'inch')

# %% [markdown]
# ### Exploring COCO data structure

# %%
import json

# %%
coco_val_2017json = "/home/bony/Downloads/coco/annotations/instances_val2017.json"

# %%
with open(coco_val_2017json, "r") as coco_json:
    data = coco_json.read()
coco_json_dict = json.loads(data)

# %%
# COCO data is a dict and has 5 keys
for k in coco_json_dict:
    print(k, len(coco_json_dict[k]))
# Out:
# info 6
# licenses 8
# images 5000
# annotations 36781
# categories 80

# %%
# Explore "info" key
coco_json_dict['info']
# Out:
# {'description': 'COCO 2017 Dataset',
#  'url': 'http://cocodataset.org',
#  'version': '1.0',
#  'year': 2017,
#  'contributor': 'COCO Consortium',
#  'date_created': '2017/09/01'}

# %%
# Explore "license" key
coco_json_dict['licenses']
# Out:
# [{'url': 'http://creativecommons.org/licenses/by-nc-sa/2.0/',
#   'id': 1,
#   'name': 'Attribution-NonCommercial-ShareAlike License'},
#  {'url': 'http://creativecommons.org/licenses/by-nc/2.0/',
#   'id': 2,
#   'name': 'Attribution-NonCommercial License'},
#  {'url': 'http://creativecommons.org/licenses/by-nc-nd/2.0/',
#   'id': 3,
#   'name': 'Attribution-NonCommercial-NoDerivs License'},
#  {'url': 'http://creativecommons.org/licenses/by/2.0/',
#   'id': 4,
#   'name': 'Attribution License'},
#  {'url': 'http://creativecommons.org/licenses/by-sa/2.0/',
#   'id': 5,
#   'name': 'Attribution-ShareAlike License'},
#  {'url': 'http://creativecommons.org/licenses/by-nd/2.0/',
#   'id': 6,
#   'name': 'Attribution-NoDerivs License'},
#  {'url': 'http://flickr.com/commons/usage/',
#   'id': 7,
#   'name': 'No known copyright restrictions'},
#  {'url': 'http://www.usa.gov/copyright.shtml',
#   'id': 8,
#   'name': 'United States Government Work'}]

# %%
# Explore "categories" key
coco_json_dict['categories']
# Out:
# [{'supercategory': 'person', 'id': 1, 'name': 'person'},
#  {'supercategory': 'vehicle', 'id': 2, 'name': 'bicycle'},
#  {'supercategory': 'vehicle', 'id': 3, 'name': 'car'},
#  {'supercategory': 'vehicle', 'id': 4, 'name': 'motorcycle'},
#  {'supercategory': 'vehicle', 'id': 5, 'name': 'airplane'},
#  {'supercategory': 'vehicle', 'id': 6, 'name': 'bus'},
#  {'supercategory': 'vehicle', 'id': 7, 'name': 'train'},
#  {'supercategory': 'vehicle', 'id': 8, 'name': 'truck'},
#  {'supercategory': 'vehicle', 'id': 9, 'name': 'boat'},
#  {'supercategory': 'outdoor', 'id': 10, 'name': 'traffic light'},
#  {'supercategory': 'outdoor', 'id': 11, 'name': 'fire hydrant'},
#  {'supercategory': 'outdoor', 'id': 13, 'name': 'stop sign'},
#  {'supercategory': 'outdoor', 'id': 14, 'name': 'parking meter'},
#  {'supercategory': 'outdoor', 'id': 15, 'name': 'bench'},
#  {'supercategory': 'animal', 'id': 16, 'name': 'bird'},
#  {'supercategory': 'animal', 'id': 17, 'name': 'cat'},
#  {'supercategory': 'animal', 'id': 18, 'name': 'dog'},
#  {'supercategory': 'animal', 'id': 19, 'name': 'horse'},
#  {'supercategory': 'animal', 'id': 20, 'name': 'sheep'},
#  {'supercategory': 'animal', 'id': 21, 'name': 'cow'},
#  {'supercategory': 'animal', 'id': 22, 'name': 'elephant'},
#  {'supercategory': 'animal', 'id': 23, 'name': 'bear'},
#  {'supercategory': 'animal', 'id': 24, 'name': 'zebra'},
#  {'supercategory': 'animal', 'id': 25, 'name': 'giraffe'},
#  {'supercategory': 'accessory', 'id': 27, 'name': 'backpack'},
#  {'supercategory': 'accessory', 'id': 28, 'name': 'umbrella'},
#  {'supercategory': 'accessory', 'id': 31, 'name': 'handbag'},
#  {'supercategory': 'accessory', 'id': 32, 'name': 'tie'},
#  {'supercategory': 'accessory', 'id': 33, 'name': 'suitcase'},
#  {'supercategory': 'sports', 'id': 34, 'name': 'frisbee'},
#  {'supercategory': 'sports', 'id': 35, 'name': 'skis'},
#  {'supercategory': 'sports', 'id': 36, 'name': 'snowboard'},
#  {'supercategory': 'sports', 'id': 37, 'name': 'sports ball'},
#  {'supercategory': 'sports', 'id': 38, 'name': 'kite'},
#  {'supercategory': 'sports', 'id': 39, 'name': 'baseball bat'},
#  {'supercategory': 'sports', 'id': 40, 'name': 'baseball glove'},
#  {'supercategory': 'sports', 'id': 41, 'name': 'skateboard'},
#  {'supercategory': 'sports', 'id': 42, 'name': 'surfboard'},
#  {'supercategory': 'sports', 'id': 43, 'name': 'tennis racket'},
#  {'supercategory': 'kitchen', 'id': 44, 'name': 'bottle'},
#  {'supercategory': 'kitchen', 'id': 46, 'name': 'wine glass'},
#  {'supercategory': 'kitchen', 'id': 47, 'name': 'cup'},
#  {'supercategory': 'kitchen', 'id': 48, 'name': 'fork'},
#  {'supercategory': 'kitchen', 'id': 49, 'name': 'knife'},
#  {'supercategory': 'kitchen', 'id': 50, 'name': 'spoon'},
#  {'supercategory': 'kitchen', 'id': 51, 'name': 'bowl'},
#  {'supercategory': 'food', 'id': 52, 'name': 'banana'},
#  {'supercategory': 'food', 'id': 53, 'name': 'apple'},
#  {'supercategory': 'food', 'id': 54, 'name': 'sandwich'},
#  {'supercategory': 'food', 'id': 55, 'name': 'orange'},
#  {'supercategory': 'food', 'id': 56, 'name': 'broccoli'},
#  {'supercategory': 'food', 'id': 57, 'name': 'carrot'},
#  {'supercategory': 'food', 'id': 58, 'name': 'hot dog'},
#  {'supercategory': 'food', 'id': 59, 'name': 'pizza'},
#  {'supercategory': 'food', 'id': 60, 'name': 'donut'},
#  {'supercategory': 'food', 'id': 61, 'name': 'cake'},
#  {'supercategory': 'furniture', 'id': 62, 'name': 'chair'},
#  {'supercategory': 'furniture', 'id': 63, 'name': 'couch'},
#  {'supercategory': 'furniture', 'id': 64, 'name': 'potted plant'},
#  {'supercategory': 'furniture', 'id': 65, 'name': 'bed'},
#  {'supercategory': 'furniture', 'id': 67, 'name': 'dining table'},
#  {'supercategory': 'furniture', 'id': 70, 'name': 'toilet'},
#  {'supercategory': 'electronic', 'id': 72, 'name': 'tv'},
#  {'supercategory': 'electronic', 'id': 73, 'name': 'laptop'},
#  {'supercategory': 'electronic', 'id': 74, 'name': 'mouse'},
#  {'supercategory': 'electronic', 'id': 75, 'name': 'remote'},
#  {'supercategory': 'electronic', 'id': 76, 'name': 'keyboard'},
#  {'supercategory': 'electronic', 'id': 77, 'name': 'cell phone'},
#  {'supercategory': 'appliance', 'id': 78, 'name': 'microwave'},
#  {'supercategory': 'appliance', 'id': 79, 'name': 'oven'},
#  {'supercategory': 'appliance', 'id': 80, 'name': 'toaster'},
#  {'supercategory': 'appliance', 'id': 81, 'name': 'sink'},
#  {'supercategory': 'appliance', 'id': 82, 'name': 'refrigerator'},
#  {'supercategory': 'indoor', 'id': 84, 'name': 'book'},
#  {'supercategory': 'indoor', 'id': 85, 'name': 'clock'},
#  {'supercategory': 'indoor', 'id': 86, 'name': 'vase'},
#  {'supercategory': 'indoor', 'id': 87, 'name': 'scissors'},
#  {'supercategory': 'indoor', 'id': 88, 'name': 'teddy bear'},
#  {'supercategory': 'indoor', 'id': 89, 'name': 'hair drier'},
#  {'supercategory': 'indoor', 'id': 90, 'name': 'toothbrush'}]

# %%
# Explore "images" key
coco_json_dict['images'][0]

#type(coco_json_dict['images'])
# Out:
# {'license': 4,
#  'file_name': '000000397133.jpg',
#  'coco_url': 'http://images.cocodataset.org/val2017/000000397133.jpg',
#  'height': 427,
#  'width': 640,
#  'date_captured': '2013-11-14 17:02:52',
#  'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg',
#  'id': 397133}

# %%
# Explore "annotations" key
# the value is a list of all the annotations

# Each annotation is a dict
coco_json_dict['annotations'][0]
print(f"keys in annotation number 0:  \n{coco_json_dict['annotations'][0].keys()}")


for item in coco_json_dict['annotations'][500].items():
    print("\n", item[0])
    print(item[1])
# Out:
# keys in annotation number 0:
# dict_keys(['segmentation', 'area', 'iscrowd', 'image_id', 'bbox', 'category_id', 'id'])
#
#  segmentation
# [[140.88, 150.48, 176.1, 150.48, 217.72, 152.89, 245.74, 140.08, 242.54, 116.87, 262.55, 110.46, 294.57, 151.28, 308.17, 144.88, 328.18, 152.09, 344.19, 160.09, 336.19, 165.69, 304.17, 158.49, 294.57, 162.49, 312.98, 187.3, 342.59, 185.7, 362.6, 215.32, 352.2, 244.14, 319.38, 255.34, 297.77, 237.73, 292.16, 208.12, 289.76, 200.91, 297.77, 187.3, 286.56, 164.89, 276.96, 190.51, 273.75, 200.11, 280.96, 214.52, 261.75, 208.92, 227.33, 222.52, 225.73, 219.32, 202.51, 224.93, 185.7, 260.95, 153.69, 264.15, 136.08, 236.13, 137.68, 212.92, 172.1, 195.31, 192.91, 208.12, 196.91, 190.51, 175.3, 184.1, 154.49, 172.1, 155.29, 160.89, 144.08, 154.49]]
#
#  area
# 16329.365099999994
#
#  iscrowd
# 0
#
#  image_id
# 102331
#
#  bbox
# [136.08, 110.46, 226.52, 153.69]
#
#  category_id
# 4
#
#  id
# 151869

# %% [markdown]
# ### Now we will transform our data to COCO format

# %%
# do not run this
#create_image_patches(slide_dir, DB, 624)

# %% [markdown]
# #### Convert data to COCO object detection format

# %%
data_to_coco_format = {}

license = licenses()
data_to_coco_format['license'] = license

info_dict = info()
data_to_coco_format['info'] = info()

data_to_coco_format['categories'] = categories()

# %%
data_to_coco_format
# Out:
# {'license': [{'url': 'http://creativecommons.org/licenses/by-nc-sa/2.0/',
#    'id': 1,
#    'name': 'Attribution-NonCommercial-ShareAlike License'}],
#  'info': {'info': {'description': 'Canine Breast Cancer',
#    'url': 'https://doi.org/10.1038/s41597-020-00756-z',
#    'version': '1.0',
#    'year': 2020,
#    'contributor': 'R Klopfleisch',
#    'date_created': '2020/09/01'}},
#  'categories': [{'supercategory': 'cell',
#    'id': 1,
#    'name': 'mitotic_look_alike'},
#   {'supercategory': 'cell', 'id': 2, 'name': 'mitotic'},
#   {'supercategory': 'cell', 'id': 3, 'name': 'background'}]}

# %% [markdown]
# #### Create dict for key = "annotations"

# %%
# get a particular slide
slide_list = database.listOfSlides()
annot_count = 0

patch_size = 624
bbox_length = 50

coco_type_annotations = []

for item in slide_list:
    #print(item)
    slide_num = item[0]
    
    currslide, filename = item
    print("\n",currslide, filename)

    #load the WSI into memory
    database.loadIntoMemory(currslide)
    annot_count += len(database.annotations.keys())
    #print(annot_count, database.())
    
    slide_path = os.path.join(slide_dir, filename)  #basepath + os.sep + filename
    slide = openslide.open_slide(str(slide_path))
    
    (wsi_x, wsi_y) = slide.dimensions
    patch_count_in_wsi = calculate_patch_count_in_WSI(wsi_x, wsi_y, patch_size)
    print(f"Slide dimension: {wsi_x, wsi_y}, number of patches : {patch_count_in_wsi} of size: {patch_size}")
    
    single_img_annotations = database.annotations
    
    print(len(single_img_annotations.items()))
    for uid, annotation in single_img_annotations.items():
        annot_details = {}
        
        annotation = single_img_annotations[uid]
        if annotation.deleted or annotation.annotationType != AnnotationType.SPOT:
            continue
        else:
            #get X and Y coordinates of the annotation
            x = annotation.x1 
            y = annotation.y1
            agreed_classs = annotation.agreedClass
            annot_uid = annotation.uid #unique ID of the annotation
            #print(annotation.annotationType, annotation.agreedClass, x, y)
            bbox = calculate_bbox(x,y)
            
            (nx,ny) = find_patch_index_within_WSI(x, y, patch_size)
            img_id = create_patch_center_identifier(filename, nx, ny)
            
            'segmentation', 'area', 'iscrowd', 'image_id', 'bbox', 'category_id', 'id'
            annot_details['id'] = uid
            annot_details['category_id'] = agreed_classs
            annot_details['image_id'] = img_id
            annot_details['iscrowd'] = 0
            annot_details['area'] = bbox_length**2
            annot_details['segmentation'] = []
            annot_details['bbox'] = bbox
            
            coco_type_annotations.append(annot_details)
            

data_to_coco_format['annotations'] = coco_type_annotations
# Out:
#  1 a8773be388e12df89edd.svs
# Slide dimension: (61199, 57462), number of patches : 9016 of size: 624
# 667
#
#  2 460906c0b1fe17ea5354.svs
# Slide dimension: (136800, 63831), number of patches : 22338 of size: 624
# 3223
#
#  3 2d56d1902ca533a5b509.svs
# Slide dimension: (70199, 65453), number of patches : 11648 of size: 624
# 522
#
#  5 d0423ef9a648bb66a763.svs
# Slide dimension: (116999, 85208), number of patches : 25432 of size: 624
# 2009
#
#  6 50cf88e9a33df0c0c8f9.svs
# Slide dimension: (125999, 87273), number of patches : 27939 of size: 624
# 3890
#
#  7 da18e7b9846e9d38034c.svs
# Slide dimension: (95399, 84305), number of patches : 20520 of size: 624
# 1567
#
#  8 d7a8af121d7d4f3fbf01.svs
# Slide dimension: (111599, 88592), number of patches : 25098 of size: 624
# 3122
#
#  9 2191a7aa287ce1d5dbc0.svs
# Slide dimension: (98999, 82534), number of patches : 20856 of size: 624
# 4097
#
#  10 69a02453620ade0edefd.svs
# Slide dimension: (97199, 90076), number of patches : 22320 of size: 624
# 2151
#
#  11 c4b95da36e32993289cb.svs
# Slide dimension: (124199, 84710), number of patches : 26865 of size: 624
# 4060
#
#  12 fa4959e484beec77543b.svs
# Slide dimension: (118799, 84406), number of patches : 25650 of size: 624
# 6444
#
#  13 72c93e042d0171a61012.svs
# Slide dimension: (122399, 78623), number of patches : 24500 of size: 624
# 838
#
#  14 4eee7b944ad5e46c60ce.svs
# Slide dimension: (44999, 47721), number of patches : 5472 of size: 624
# 258
#
#  15 b1bdee8e5e3372174619.svs
# Slide dimension: (125999, 83745), number of patches : 26934 of size: 624
# 2697
#
#  16 3d3d04eca056556b0b26.svs
# Slide dimension: (109799, 87152), number of patches : 24325 of size: 624
# 4399
#
#  17 084383c18b9060880e82.svs
# Slide dimension: (61199, 82153), number of patches : 12838 of size: 624
# 722
#
#  18 e09512d530d933e436d5.svs
# Slide dimension: (107999, 81548), number of patches : 22490 of size: 624
# 841
#
#  19 d37ab62158945f22deed.svs
# Slide dimension: (122399, 77178), number of patches : 24108 of size: 624
# 2378
#
#  20 deb768e5efb9d1dcbc13.svs
# Slide dimension: (104399, 76426), number of patches : 20374 of size: 624
# 569
#
#  21 022857018aa597374b6c.svs
# Slide dimension: (109799, 84591), number of patches : 23625 of size: 624
# 4451
#
#  22 13528f1921d4f1f15511.svs
# Slide dimension: (131400, 83891), number of patches : 28140 of size: 624
# 1429

# %%
len(data_to_coco_format['annotations'])
#calculate_bbox(100, 100), patch_size*patch_size
# Out:
# 50282

# %%
data_to_coco_format['annotations'][100]
# Out:
# {'id': 105,
#  'category_id': 2,
#  'image_id': 'a8773be388e12df89edd.svs_22_55.jpg',
#  'iscrowd': 0,
#  'area': 2500,
#  'segmentation': [],
#  'bbox': [14268, 34654, 14318, 34704]}

# %% [markdown]
# #### Create dict for key = "images"

# %%
data_to_coco_format['images'] = create_image_patches(slide_dir, DB, patch_size)
# Out:
# Slide number: 1,  Name: a8773be388e12df89edd.svs, Slide dimension: (61199, 57462)
#
# 1000   ***   {'license': 1, 'file_name': ('a8773be388e12df89edd.svs_10_79.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 1000}
# 2000   ***   {'license': 1, 'file_name': ('a8773be388e12df89edd.svs_21_67.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 2000}
# 3000   ***   {'license': 1, 'file_name': ('a8773be388e12df89edd.svs_32_55.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 3000}
# 4000   ***   {'license': 1, 'file_name': ('a8773be388e12df89edd.svs_43_43.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 4000}
# 5000   ***   {'license': 1, 'file_name': ('a8773be388e12df89edd.svs_54_31.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 5000}
# 6000   ***   {'license': 1, 'file_name': ('a8773be388e12df89edd.svs_65_19.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 6000}
# 7000   ***   {'license': 1, 'file_name': ('a8773be388e12df89edd.svs_76_7.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 7000}
# 8000   ***   {'license': 1, 'file_name': ('a8773be388e12df89edd.svs_86_87.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 8000}
# 9000   ***   {'license': 1, 'file_name': ('a8773be388e12df89edd.svs_97_75.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 9000}
#
#
# Slide number: 2,  Name: 460906c0b1fe17ea5354.svs, Slide dimension: (136800, 63831)
#
# 10000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_9_65.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 10000}
# 11000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_19_45.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 11000}
# 12000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_29_25.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 12000}
# 13000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_39_5.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 13000}
# 14000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_48_87.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 14000}
# 15000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_58_67.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 15000}
# 16000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_68_47.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 16000}
# 17000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_78_27.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 17000}
# 18000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_88_7.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 18000}
# 19000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_97_89.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 19000}
# 20000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_107_69.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 20000}
# 21000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_117_49.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 21000}
# 22000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_127_29.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 22000}
# 23000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_137_9.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 23000}
# 24000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_146_91.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 24000}
# 25000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_156_71.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 25000}
# 26000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_166_51.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 26000}
# 27000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_176_31.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 27000}
# 28000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_186_11.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 28000}
# 29000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_195_93.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 29000}
# 30000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_205_73.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 30000}
# 31000   ***   {'license': 1, 'file_name': ('460906c0b1fe17ea5354.svs_215_53.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 31000}
#
#
# Slide number: 3,  Name: 2d56d1902ca533a5b509.svs, Slide dimension: (70199, 65453)
#
# 32000   ***   {'license': 1, 'file_name': ('2d56d1902ca533a5b509.svs_6_21.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 32000}
# 33000   ***   {'license': 1, 'file_name': ('2d56d1902ca533a5b509.svs_15_85.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 33000}
# 34000   ***   {'license': 1, 'file_name': ('2d56d1902ca533a5b509.svs_25_45.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 34000}
# 35000   ***   {'license': 1, 'file_name': ('2d56d1902ca533a5b509.svs_35_5.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 35000}
# 36000   ***   {'license': 1, 'file_name': ('2d56d1902ca533a5b509.svs_44_69.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 36000}
# 37000   ***   {'license': 1, 'file_name': ('2d56d1902ca533a5b509.svs_54_29.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 37000}
# 38000   ***   {'license': 1, 'file_name': ('2d56d1902ca533a5b509.svs_63_93.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 38000}
# 39000   ***   {'license': 1, 'file_name': ('2d56d1902ca533a5b509.svs_73_53.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 39000}
# 40000   ***   {'license': 1, 'file_name': ('2d56d1902ca533a5b509.svs_83_13.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 40000}
# 41000   ***   {'license': 1, 'file_name': ('2d56d1902ca533a5b509.svs_92_77.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 41000}
# 42000   ***   {'license': 1, 'file_name': ('2d56d1902ca533a5b509.svs_102_37.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 42000}
# 43000   ***   {'license': 1, 'file_name': ('2d56d1902ca533a5b509.svs_111_101.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 43000}
#
#
# Slide number: 5,  Name: d0423ef9a648bb66a763.svs, Slide dimension: (116999, 85208)
#
# 44000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_7_45.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 44000}
# 45000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_14_93.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 45000}
# 46000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_22_5.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 46000}
# 47000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_29_53.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 47000}
# 48000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_36_101.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 48000}
# 49000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_44_13.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 49000}
# 50000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_51_61.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 50000}
# 51000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_58_109.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 51000}
# 52000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_66_21.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 52000}
# 53000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_73_69.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 53000}
# 54000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_80_117.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 54000}
# 55000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_88_29.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 55000}
# 56000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_95_77.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 56000}
# 57000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_102_125.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 57000}
# 58000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_110_37.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 58000}
# 59000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_117_85.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 59000}
# 60000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_124_133.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 60000}
# 61000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_132_45.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 61000}
# 62000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_139_93.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 62000}
# 63000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_147_5.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 63000}
# 64000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_154_53.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 64000}
# 65000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_161_101.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 65000}
# 66000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_169_13.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 66000}
# 67000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_176_61.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 67000}
# 68000   ***   {'license': 1, 'file_name': ('d0423ef9a648bb66a763.svs_183_109.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 68000}
#
#
# Slide number: 6,  Name: 50cf88e9a33df0c0c8f9.svs, Slide dimension: (125999, 87273)
#
# 69000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_4_9.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 69000}
# 70000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_11_36.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 70000}
# 71000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_18_63.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 71000}
# 72000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_25_90.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 72000}
# 73000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_32_117.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 73000}
# 74000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_40_5.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 74000}
# 75000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_47_32.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 75000}
# 76000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_54_59.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 76000}
# 77000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_61_86.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 77000}
# 78000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_68_113.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 78000}
# 79000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_76_1.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 79000}
# 80000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_83_28.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 80000}
# 81000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_90_55.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 81000}
# 82000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_97_82.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 82000}
# 83000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_104_109.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 83000}
# 84000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_111_136.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 84000}
# 85000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_119_24.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 85000}
# 86000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_126_51.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 86000}
# 87000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_133_78.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 87000}
# 88000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_140_105.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 88000}
# 89000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_147_132.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 89000}
# 90000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_155_20.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 90000}
# 91000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_162_47.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 91000}
# 92000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_169_74.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 92000}
# 93000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_176_101.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 93000}
# 94000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_183_128.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 94000}
# 95000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_191_16.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 95000}
# 96000   ***   {'license': 1, 'file_name': ('50cf88e9a33df0c0c8f9.svs_198_43.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 96000}
#
#
# Slide number: 7,  Name: da18e7b9846e9d38034c.svs, Slide dimension: (95399, 84305)
#
# 97000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_4_86.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 97000}
# 98000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_12_6.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 98000}
# 99000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_19_61.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 99000}
# 100000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_26_116.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 100000}
# 101000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_34_36.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 101000}
# 102000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_41_91.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 102000}
# 103000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_49_11.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 103000}
# 104000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_56_66.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 104000}
# 105000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_63_121.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 105000}
# 106000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_71_41.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 106000}
# 107000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_78_96.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 107000}
# 108000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_86_16.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 108000}
# 109000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_93_71.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 109000}
# 110000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_100_126.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 110000}
# 111000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_108_46.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 111000}
# 112000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_115_101.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 112000}
# 113000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_123_21.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 113000}
# 114000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_130_76.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 114000}
# 115000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_137_131.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 115000}
# 116000   ***   {'license': 1, 'file_name': ('da18e7b9846e9d38034c.svs_145_51.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 116000}
#
#
# Slide number: 8,  Name: d7a8af121d7d4f3fbf01.svs, Slide dimension: (111599, 88592)
#
# 117000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_0_106.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 117000}
# 118000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_7_119.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 118000}
# 119000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_14_132.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 119000}
# 120000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_22_4.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 120000}
# 121000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_29_17.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 121000}
# 122000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_36_30.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 122000}
# 123000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_43_43.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 123000}
# 124000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_50_56.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 124000}
# 125000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_57_69.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 125000}
# 126000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_64_82.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 126000}
# 127000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_71_95.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 127000}
# 128000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_78_108.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 128000}
# 129000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_85_121.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 129000}
# 130000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_92_134.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 130000}
# 131000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_100_6.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 131000}
# 132000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_107_19.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 132000}
# 133000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_114_32.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 133000}
# 134000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_121_45.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 134000}
# 135000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_128_58.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 135000}
# 136000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_135_71.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 136000}
# 137000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_142_84.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 137000}
# 138000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_149_97.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 138000}
# 139000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_156_110.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 139000}
# 140000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_163_123.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 140000}
# 141000   ***   {'license': 1, 'file_name': ('d7a8af121d7d4f3fbf01.svs_170_136.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 141000}
#
#
# Slide number: 9,  Name: 2191a7aa287ce1d5dbc0.svs, Slide dimension: (98999, 82534)
#
# 142000   ***   {'license': 1, 'file_name': ('2191a7aa287ce1d5dbc0.svs_0_8.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 142000}
# 143000   ***   {'license': 1, 'file_name': ('2191a7aa287ce1d5dbc0.svs_7_84.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 143000}
# 144000   ***   {'license': 1, 'file_name': ('2191a7aa287ce1d5dbc0.svs_15_28.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 144000}
# 145000   ***   {'license': 1, 'file_name': ('2191a7aa287ce1d5dbc0.svs_22_104.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 145000}
# 146000   ***   {'license': 1, 'file_name': ('2191a7aa287ce1d5dbc0.svs_30_48.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 146000}
# ...
# 402000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_24_36.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 402000}
# 403000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_31_91.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 403000}
# 404000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_39_11.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 404000}
# 405000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_46_66.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 405000}
# 406000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_53_121.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 406000}
# 407000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_61_41.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 407000}
# 408000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_68_96.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 408000}
# 409000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_76_16.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 409000}
# 410000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_83_71.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 410000}
# 411000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_90_126.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 411000}
# 412000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_98_46.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 412000}
# 413000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_105_101.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 413000}
# 414000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_113_21.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 414000}
# 415000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_120_76.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 415000}
# 416000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_127_131.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 416000}
# 417000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_135_51.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 417000}
# 418000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_142_106.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 418000}
# 419000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_150_26.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 419000}
# 420000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_157_81.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 420000}
# 421000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_165_1.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 421000}
# 422000   ***   {'license': 1, 'file_name': ('022857018aa597374b6c.svs_172_56.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 422000}
#
#
# Slide number: 22,  Name: 13528f1921d4f1f15511.svs, Slide dimension: (131400, 83891)
#
# 423000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_4_115.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 423000}
# 424000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_12_43.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 424000}
# 425000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_19_105.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 425000}
# 426000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_27_33.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 426000}
# 427000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_34_95.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 427000}
# 428000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_42_23.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 428000}
# 429000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_49_85.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 429000}
# 430000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_57_13.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 430000}
# 431000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_64_75.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 431000}
# 432000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_72_3.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 432000}
# 433000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_79_65.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 433000}
# 434000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_86_127.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 434000}
# 435000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_94_55.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 435000}
# 436000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_101_117.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 436000}
# 437000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_109_45.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 437000}
# 438000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_116_107.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 438000}
# 439000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_124_35.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 439000}
# 440000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_131_97.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 440000}
# 441000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_139_25.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 441000}
# 442000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_146_87.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 442000}
# 443000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_154_15.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 443000}
# 444000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_161_77.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 444000}
# 445000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_169_5.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 445000}
# 446000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_176_67.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 446000}
# 447000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_183_129.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 447000}
# 448000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_191_57.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 448000}
# 449000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_198_119.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 449000}
# 450000   ***   {'license': 1, 'file_name': ('13528f1921d4f1f15511.svs_206_47.jpg',), 'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',), 'height': 624, 'width': 624, 'date_captured': ('2013-11-14 17:02:52',), 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 450000}

# %%
data_to_coco_format['images'][100]
# Out:
# {'license': 1,
#  'file_name': ('a8773be388e12df89edd.svs_1_8.jpg',),
#  'coco_url': ('http://images.cocodataset.org/val2017/000000397133.jpg',),
#  'height': 624,
#  'width': 624,
#  'date_captured': ('2013-11-14 17:02:52',),
#  'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg',
#  'id': 101}
